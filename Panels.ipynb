# %%
import pandas as pd

# %%
from pandas_datareader import data

# %%
companies = ["MSFT" , "GOOG" , "AAPL" , "YHOO" , "AMZN"]

# %%
data.DataReader(name=companies, data_source = "yahoo" , start= 2018-1-1,end = 2020-1-1)
# Out:
# Attributes  Adj Close                                                 Close  \
# Symbols          MSFT         GOOG        AAPL         AMZN YHOO       MSFT
# Date
# 2015-12-31  51.024227   758.880005   98.129669   675.890015  NaN  55.480000
# 2016-01-04  50.398834   741.840027   98.213585   636.989990  NaN  54.799999
# 2016-01-05  50.628761   742.580017   95.752419   633.789978  NaN  55.049999
# 2016-01-06  49.709072   743.619995   93.878586   632.650024  NaN  54.049999
# 2016-01-07  47.980057   726.390015   89.916473   607.940002  NaN  52.169998
# ...               ...          ...         ...          ...  ...        ...
# 2017-12-22  82.604538  1060.119995  169.466919  1168.359985  NaN  85.510002
# 2017-12-26  82.498283  1056.739990  165.167572  1176.760010  NaN  85.400002
# 2017-12-27  82.797745  1049.369995  165.196625  1182.260010  NaN  85.709999
# 2017-12-28  82.807411  1048.140015  165.661407  1186.099976  NaN  85.720001
# ...

# %%
p=p.unstack()

# %%
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
p.shape
# Out:
# (504, 30)

# %%
open=p["Open"]

# %%
open.index
# Out:
# DatetimeIndex(['2015-12-31', '2016-01-04', '2016-01-05', '2016-01-06',
#                '2016-01-07', '2016-01-08', '2016-01-11', '2016-01-12',
#                '2016-01-13', '2016-01-14',
#                ...
#                '2017-12-15', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22', '2017-12-26', '2017-12-27',
#                '2017-12-28', '2017-12-29'],
#               dtype='datetime64[ns]', name='Date', length=504, freq=None)
