# %% [markdown]
# ## Data analysis

# %%
import pandas as pd
df3=pd.read_csv("D:\\bigfile.csv",index_col="First Name")

# %%
df3
# Out:
#             Emp_ID Name_Prefix Middle_Initial    Last_Name Gender  \
# First Name
# Hermila     857211         Ms.              J         Suhr      F
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
# ...            ...         ...            ...          ...    ...
# Doreen      957337         Ms.              R      Baisden      F
# Kecia       745592        Mrs.              J     Santiago      F
# Jestine     192620        Mrs.              T         Sugg      F
# Johnson     249486         Mr.              N    Mclelland      M
# Rob         829485         Dr.              T       Swoope      M
#
#                                  E_Mail         Father's_Name  \
# First Name
# Hermila          hermila.suhr@gmail.com             Todd Suhr
# ...

# %%
df3.axes
# Out:
# [Index(['Hermila', 'Antonio', 'Sebastian', 'Alec', 'Reggie', 'Elisha', 'Danilo',
#         'Madalene', 'Micheal', 'Wilma',
#         ...
#         'Richard', 'Chery', 'Garfield', 'Shaina', 'Pierre', 'Doreen', 'Kecia',
#         'Jestine', 'Johnson', 'Rob'],
#        dtype='object', name='First Name', length=500000),
#  Index(['Emp ID', 'Name Prefix', 'Middle Initial', 'Last Name', 'Gender',
#         'E Mail', 'Father's Name', 'Mother's Name', 'Mother's Maiden Name',
#         'Date of Birth', 'Time of Birth', 'Age in Yrs.', 'Weight in Kgs.',
#         'Date of Joining', 'Quarter of Joining', 'Half of Joining',
#         'Year of Joining', 'Month of Joining', 'Month Name of Joining',
#         'Short Month', 'Day of Joining', 'DOW of Joining', 'Short DOW',
#         'Age in Company (Years)', 'Salary', 'Last % Hike', 'SSN', 'Phone No. ',
#         'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#         'Password'],
#        dtype='object')]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 37 columns):
# Emp ID                    500000 non-null int64
# Name Prefix               500000 non-null object
# First Name                500000 non-null object
# Middle Initial            500000 non-null object
# Last Name                 500000 non-null object
# Gender                    500000 non-null object
# E Mail                    500000 non-null object
# Father's Name             500000 non-null object
# Mother's Name             500000 non-null object
# Mother's Maiden Name      500000 non-null object
# Date of Birth             500000 non-null object
# Time of Birth             500000 non-null object
# Age in Yrs.               500000 non-null float64
# Weight in Kgs.            500000 non-null int64
# Date of Joining           500000 non-null object
# Quarter of Joining        500000 non-null object
# Half of Joining           500000 non-null object
# ...

# %%
df3.sort_values("First Name")
# Out:
#             Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Aaron       364847       Prof.              S  Birdsall      M
# Aaron       922133        Mrs.              E    Keyser      F
# Aaron       279293         Mr.              S   Dorsett      M
# Aaron       188684        Mrs.              X    Fricke      F
# Aaron       698511         Mr.              B   Hibbler      M
# ...            ...         ...            ...       ...    ...
# Zulma       422832         Ms.              Y   Hatcher      F
# Zulma       904654         Ms.              P    Klimek      F
# Zulma       118130         Ms.              K    Sowder      F
# Zulma       404196        Drs.              T  Matherly      F
# Zulma       151035        Mrs.              K   Trisler      F
#
#                                  E Mail     Father's Name     Mother's Name  \
# First Name
# Aaron        aaron.birdsall@charter.net     Dirk Birdsall  Lavenia Birdsall
# ...

# %%
df3.index.unique()
#df3.iloc[0]
# Out:
# Index(['Hermila', 'Antonio', 'Sebastian', 'Alec', 'Reggie', 'Elisha', 'Danilo',
#        'Madalene', 'Micheal', 'Wilma',
#        ...
#        'Jessia', 'Cinderella', 'Griselda', 'Delaine', 'Evonne', 'Olga',
#        'Sasha', 'Oralia', 'Celeste', 'Alyssa'],
#       dtype='object', name='First Name', length=5163)

# %%
"Aaron" in df3.index
# Out:
# True

# %%
df3.ix[0:5]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#             Emp ID Name Prefix Middle Initial    Last Name Gender  \
# First Name
# Hermila     857211         Ms.              J         Suhr      F
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
#
#                                 E Mail         Father's Name  \
# First Name
# Hermila         hermila.suhr@gmail.com             Todd Suhr
# Antonio          antonio.joy@yahoo.com             Clark Joy
# ...

# %%
df3.iloc[4:8]
# Out:
#             Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Reggie      690850         Mr.              C   Doughty      M
# Elisha      358257       Prof.              B    Bottom      M
# Danilo      303899         Mr.              R     Irwin      M
# Madalene    901163         Ms.              D    Dierks      F
#
#                                E Mail   Father's Name   Mother's Name  \
# First Name
# Reggie       reggie.doughty@gmail.com  Jerrod Doughty  Crista Doughty
# Elisha        elisha.bottom@yahoo.com  Nicolas Bottom       Nu Bottom
# Danilo         danilo.irwin@gmail.com       Ron Irwin  Angelina Irwin
# Madalene    madalene.dierks@yahoo.com    Efren Dierks  Rebbeca Dierks
#
#            Mother's Maiden Name Date of Birth  ...          SSN    Phone No.   \
# First Name                                     ...
# Reggie                    Abron    11/27/1966  ...  321-11-0416  314-677-4501
# ...

# %%
df3.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'Middle Initial', 'Last Name', 'Gender',
#        'E Mail', 'Father's Name', 'Mother's Name', 'Mother's Maiden Name',
#        'Date of Birth', 'Time of Birth', 'Age in Yrs.', 'Weight in Kgs.',
#        'Date of Joining', 'Quarter of Joining', 'Half of Joining',
#        'Year of Joining', 'Month of Joining', 'Month Name of Joining',
#        'Short Month', 'Day of Joining', 'DOW of Joining', 'Short DOW',
#        'Age in Company (Years)', 'Salary', 'Last % Hike', 'SSN', 'Phone No. ',
#        'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#        'Password'],
#       dtype='object')

# %%
df3["Last Name"].is_unique
# Out:
# False

# %%
df3.iloc[0,0:3]
# Out:
# Emp ID            857211
# Name Prefix          Ms.
# Middle Initial         J
# Name: Hermila, dtype: object

# %%
df3.ix["Antonio",'E Mail']="antonio.joy@yahoo.com"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df3.ix["Antonio",'E Mail']
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# First Name
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
#                    ...
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Antonio    antonio.joy@yahoo.com
# Name: E Mail, Length: 278, dtype: object

# %%
df3.reindex()
# Out:
#             Emp ID Name Prefix Middle Initial    Last Name Gender  \
# First Name
# Hermila     857211         Ms.              J         Suhr      F
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
# ...            ...         ...            ...          ...    ...
# Doreen      957337         Ms.              R      Baisden      F
# Kecia       745592        Mrs.              J     Santiago      F
# Jestine     192620        Mrs.              T         Sugg      F
# Johnson     249486         Mr.              N    Mclelland      M
# Rob         829485         Dr.              T       Swoope      M
#
#                                  E Mail         Father's Name  \
# First Name
# Hermila          hermila.suhr@gmail.com             Todd Suhr
# ...

# %%
mask=df3["Mother's Maiden Name"]=="Mease"
mask
# Out:
# First Name
# Hermila      False
# Antonio      False
# Sebastian    False
# Alec         False
# Reggie       False
#              ...
# Doreen       False
# Kecia        False
# Jestine      False
# Johnson      False
# Rob          False
# Name: Mother's Maiden Name, Length: 500000, dtype: bool

# %%
df3.ix[mask,"Mother's Maiden Name"]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# First Name
# Alec         miss Mease
# Edgardo      miss Mease
# Kirby        miss Mease
# Gordon       miss Mease
# Micaela      miss Mease
# Yolande      miss Mease
# Antwan       miss Mease
# Arden        miss Mease
# William      miss Mease
# Effie        miss Mease
# Jacquelin    miss Mease
# Alexa        miss Mease
# Bryon        miss Mease
# Hunter       miss Mease
# Dulcie       miss Mease
# Isis         miss Mease
# Deangelo     miss Mease
# Steven       miss Mease
# Rene         miss Mease
# Brianna      miss Mease
# Talisha      miss Mease
# Leonida      miss Mease
# Lakesha      miss Mease
# Reed         miss Mease
# ...

# %%
df3[df3["Mother's Maiden Name"]=="miss Mease"]
# Out:
#             Emp ID Name Prefix Middle Initial     Last Name Gender  \
# First Name
# Alec        961057         Dr.              U         Mager      M
# Edgardo     665781         Mr.              B          Drye      M
# Kirby       328666         Ms.              H       Morvant      F
# Gordon      844903       Prof.              T      Rousseau      M
# Micaela     182439         Ms.              Y       Barlett      F
# Yolande     160649         Ms.              E      Haberman      F
# Antwan      402320         Mr.              F        Varner      M
# Arden       628084         Dr.              H       Zazueta      M
# William     645071         Mr.              S        Demers      M
# Effie       823113         Ms.              Z        Obando      F
# Jacquelin   783014        Hon.              O        Whelan      F
# Alexa       518474         Ms.              F      Bohnsack      F
# Bryon       935786        Hon.              V            Ye      M
# ...

# %%
df3.rename(index={"Hermila":"hammu"},inplace=True)

# %%
df3.drop("hammu")
# Out:
#             Emp ID Name Prefix Middle Initial    Last Name Gender  \
# First Name
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
# Elisha      358257       Prof.              B       Bottom      M
# ...            ...         ...            ...          ...    ...
# Doreen      957337         Ms.              R      Baisden      F
# Kecia       745592        Mrs.              J     Santiago      F
# Jestine     192620        Mrs.              T         Sugg      F
# Johnson     249486         Mr.              N    Mclelland      M
# Rob         829485         Dr.              T       Swoope      M
#
#                                  E Mail         Father's Name  \
# First Name
# Antonio           antonio.joy@yahoo.com             Clark Joy
# ...

# %%
df3.drop("mom",axis=1)
# Out:
#             Emp ID Name Prefix Middle Initial    Last Name Gender  \
# First Name
# hammu       857211         Ms.              J         Suhr      F
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
# ...            ...         ...            ...          ...    ...
# Doreen      957337         Ms.              R      Baisden      F
# Kecia       745592        Mrs.              J     Santiago      F
# Jestine     192620        Mrs.              T         Sugg      F
# Johnson     249486         Mr.              N    Mclelland      M
# Rob         829485         Dr.              T       Swoope      M
#
#                                  E Mail         Father's Name  \
# First Name
# hammu            hermila.suhr@gmail.com             Todd Suhr
# ...

# %%
df3.pop("hammu")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hammu'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-da1fd0b87a1f> in <module>
# ----> 1 df3.pop("hammu")
#
# ...

# %%
del df3["Emp ID"]

# %%
df3.sample(n = 9,axis=1)
# Out:
#                      City Short DOW  Age in Yrs.  Month of Joining  \
# First Name
# Hermila     Peach Orchard       Tue        24.91                 9
# Antonio        Rocky Ford       Tue        27.61                 8
# Sebastian         Antwerp       Sun        36.87                 4
# Alec        Milledgeville       Thu        43.19                 3
# Reggie        Springfield       Mon        50.70                 1
# ...                   ...       ...          ...               ...
# Doreen             Oviedo       Fri        29.59                 5
# Kecia          Piney View       Sat        42.22                 9
# Jestine           Brooten       Thu        37.63                 2
# Johnson      Forest Lakes       Tue        44.16                 2
# Rob             Moshannon       Mon        45.53                11
#
#             Year of Joining  Weight in Kgs.  Day of Joining  \
# First Name
# Hermila                2014              57               9
# ...

# %%
sal=df3.nlargest(5,"Salary")

# %%
sal["Salary"]
# Out:
# First Name
# Joanna     200000
# Mara       200000
# Jeanne     199999
# Clayton    199999
# Keiko      199999
# Name: Salary, dtype: int64

# %%
mask1=df3["Mother's Maiden Name"] == "Abron"
df3[mask]
# Out:
#             Emp ID Name Prefix Middle Initial  Last Name Gender  \
# First Name
# Reggie      690850         Mr.              C    Doughty      M
# Melba       379007         Ms.              H  Sthilaire      F
# Chadwick    469228         Mr.              G     Eckert      M
# Frank       730949         Mr.              N      Vallo      M
# Henry       111403         Mr.              F     Lawyer      M
# Otis        783474         Mr.              S    Milburn      M
# Wen         132114         Ms.              N       Jock      F
# Bernarda    321921         Ms.              L      Tutor      F
# Linnie      930781        Mrs.              O     Torian      F
# Caroyln     280082         Ms.              L  Marquette      F
# Jesus       545945         Mr.              Y     Baucom      M
# Mark        807004         Mr.              C     Joplin      M
# Julie       776930        Mrs.              U     Medlin      F
# ...

# %%
df3.where(mask)
# Out:
#               Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Hermila          NaN         NaN            NaN       NaN    NaN
# Antonio          NaN         NaN            NaN       NaN    NaN
# Sebastian        NaN         NaN            NaN       NaN    NaN
# Alec             NaN         NaN            NaN       NaN    NaN
# Reggie      690850.0         Mr.              C   Doughty      M
# ...              ...         ...            ...       ...    ...
# Doreen           NaN         NaN            NaN       NaN    NaN
# Kecia            NaN         NaN            NaN       NaN    NaN
# Jestine          NaN         NaN            NaN       NaN    NaN
# Johnson          NaN         NaN            NaN       NaN    NaN
# Rob              NaN         NaN            NaN       NaN    NaN
#
#                               E Mail   Father's Name   Mother's Name  \
# First Name
# Hermila                          NaN             NaN             NaN
# ...

# %%
mask2=(df3["Age in Yrs."]>30)

# %%
df3.where(mask1 & mask2)
# Out:
#               Emp ID Name Prefix Middle Initial Last Name Gender  \
# First Name
# Hermila          NaN         NaN            NaN       NaN    NaN
# Antonio          NaN         NaN            NaN       NaN    NaN
# Sebastian        NaN         NaN            NaN       NaN    NaN
# Alec             NaN         NaN            NaN       NaN    NaN
# Reggie      690850.0         Mr.              C   Doughty      M
# ...              ...         ...            ...       ...    ...
# Doreen           NaN         NaN            NaN       NaN    NaN
# Kecia            NaN         NaN            NaN       NaN    NaN
# Jestine          NaN         NaN            NaN       NaN    NaN
# Johnson          NaN         NaN            NaN       NaN    NaN
# Rob              NaN         NaN            NaN       NaN    NaN
#
#                               E Mail   Father's Name   Mother's Name  \
# First Name
# Hermila                          NaN             NaN             NaN
# ...

# %%
df3.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'Middle Initial', 'Last Name', 'Gender',
#        'E Mail', 'Father's Name', 'Mother's Name', 'Mother's Maiden Name',
#        'Date of Birth', 'Time of Birth', 'Age in Yrs.', 'Weight in Kgs.',
#        'Date of Joining', 'Quarter of Joining', 'Half of Joining',
#        'Year of Joining', 'Month of Joining', 'Month Name of Joining',
#        'Short Month', 'Day of Joining', 'DOW of Joining', 'Short DOW',
#        'Age in Company (Years)', 'Salary', 'Last % Hike', 'SSN', 'Phone No. ',
#        'Place Name', 'County', 'City', 'State', 'Zip', 'Region', 'User Name',
#        'Password'],
#       dtype='object')

# %%
df3.columns=[column_name.replace(" ","_") for column_name in df3.columns]

# %%
df3.columns
# Out:
# Index(['Emp_ID', 'Name_Prefix', 'Middle_Initial', 'Last_Name', 'Gender',
#        'E_Mail', 'Father's_Name', 'Mother's_Name', 'Mother's_Maiden_Name',
#        'Date_of_Birth', 'Time_of_Birth', 'Age_in_Yrs.', 'Weight_in_Kgs.',
#        'Date_of_Joining', 'Quarter_of_Joining', 'Half_of_Joining',
#        'Year_of_Joining', 'Month_of_Joining', 'Month_Name_of_Joining',
#        'Short_Month', 'Day_of_Joining', 'DOW_of_Joining', 'Short_DOW',
#        'Age_in_Company_(Years)', 'Salary', 'Last_%_Hike', 'SSN', 'Phone_No._',
#        'Place_Name', 'County', 'City', 'State', 'Zip', 'Region', 'User_Name',
#        'Password'],
#       dtype='object')

# %%
df3.query('Salary>40000')
# Out:
#             Emp_ID Name_Prefix Middle_Initial    Last_Name Gender  \
# First Name
# Hermila     857211         Ms.              J         Suhr      F
# Antonio     514341         Mr.              Q          Joy      M
# Sebastian   314598       Prof.              J       Moores      M
# Alec        987773         Mr.              S  Rittenhouse      M
# Reggie      690850         Mr.              C      Doughty      M
# ...            ...         ...            ...          ...    ...
# Doreen      957337         Ms.              R      Baisden      F
# Kecia       745592        Mrs.              J     Santiago      F
# Jestine     192620        Mrs.              T         Sugg      F
# Johnson     249486         Mr.              N    Mclelland      M
# Rob         829485         Dr.              T       Swoope      M
#
#                                  E_Mail         Father's_Name  \
# First Name
# Hermila          hermila.suhr@gmail.com             Todd Suhr
# ...

# %%
income=df3["Salary"].copy()

# %%
income
# Out:
# First Name
# Hermila      168991
# Antonio       53504
# Sebastian    158859
# Alec          76105
# Reggie       134436
#               ...
# Doreen       134337
# Kecia         73157
# Jestine      102821
# Johnson      185460
# Rob          132652
# Name: Salary, Length: 500000, dtype: int64
