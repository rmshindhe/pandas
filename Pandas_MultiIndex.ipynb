# %%
import pandas as pd
df=pd.read_csv("D:\\bigmac\\bigmac.csv",parse_dates=["date"])

# %%
df
# Out:
#                          iso_a3 currency_code  local_price     dollar_ex  \
# date       name
# 2000-04-01 Argentina        ARG           ARS         2.50      1.000000
#            Australia        AUS           AUD         2.59      1.680000
#            Brazil           BRA           BRL         2.95      1.790000
#            Britain          GBR           GBP         1.90      0.632911
#            Canada           CAN           CAD         2.85      1.470000
# ...                         ...           ...          ...           ...
# 2019-07-09 Ukraine          UKR           UAH        57.00     25.647500
#            Uruguay          URY           UYU       164.00     35.169500
#            United States    USA           USD         5.74      1.000000
#            Vietnam          VNM           VND     65000.00  23231.000000
#            South Africa     ZAF           ZAR        31.00     14.175000
#
#                           GDP_dollar
# date       name
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1514 entries, 0 to 1513
# Data columns (total 7 columns):
# name             1514 non-null object
# iso_a3           1514 non-null category
# currency_code    1514 non-null category
# local_price      1514 non-null float64
# dollar_ex        1514 non-null float64
# GDP_dollar       901 non-null float64
# date             1514 non-null datetime64[ns]
# dtypes: category(2), datetime64[ns](1), float64(3), object(1)
# memory usage: 68.2+ KB

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1514, step=1),
#  Index(['name', 'iso_a3', 'currency_code', 'local_price', 'dollar_ex',
#         'GDP_dollar', 'date'],
#        dtype='object')]

# %%
df["iso_a3"]=df["iso_a3"].astype("category")

# %%
df['currency_code']=df['currency_code'].astype('category')

# %%
df.head()
# Out:
#                      iso_a3 currency_code  local_price  dollar_ex  GDP_dollar
# date       Country
# 2000-04-01 Argentina    ARG           ARS         2.50   1.000000         NaN
#            Australia    AUS           AUD         2.59   1.680000         NaN
#            Brazil       BRA           BRL         2.95   1.790000         NaN
#            Britain      GBR           GBP         1.90   0.632911         NaN
#            Canada       CAN           CAD         2.85   1.470000         NaN

# %%
df.set_index(keys=["date","name"],inplace=True)

# %%
df.index[0]
# Out:
# (Timestamp('2000-04-01 00:00:00'), 'Argentina')

# %%
df.index.get_level_values("name")
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Czech Republic', 'Denmark', 'Euro area',
#        ...
#        'Slovenia', 'Sweden', 'Thailand', 'Turkey', 'Taiwan', 'Ukraine',
#        'Uruguay', 'United States', 'Vietnam', 'South Africa'],
#       dtype='object', name='name', length=1514)

# %%
df.index.set_names(["date","Country"],inplace=[True,False])

# %%
df.sort_index(inplace=True)

# %%
df.loc[("2000-04-01","Canada"),("local_price","dollar_ex")]
# Out:
#                     local_price  dollar_ex
# date       Country
# 2000-04-01 Canada          2.85       1.47

# %%
df.ix[("2000-04-01","Canada")]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# iso_a3            CAN
# currency_code     CAD
# local_price      2.85
# dollar_ex        1.47
# GDP_dollar        NaN
# Name: (2000-04-01 00:00:00, Canada), dtype: object

# %%
df.transpose()
# Out:
# date          2000-04-01                                                \
# Country        Argentina Australia Brazil   Britain Canada Chile China
# iso_a3               ARG       AUS    BRA       GBR    CAN   CHL   CHN
# currency_code        ARS       AUD    BRL       GBP    CAD   CLP   CNY
# local_price          2.5      2.59   2.95       1.9   2.85  1260   9.9
# dollar_ex              1      1.68   1.79  0.632911   1.47   514  8.28
# GDP_dollar           NaN       NaN    NaN       NaN    NaN   NaN   NaN
#
# date                                            ... 2019-07-09              \
# Country       Czech Republic Denmark Euro area  ...     Sweden Switzerland
# iso_a3                   CZE     DNK       EUZ  ...        SWE         CHE
# currency_code            CZK     DKK       EUR  ...        SEK         CHF
# local_price            54.37   24.75      2.56  ...         51         6.5
# dollar_ex               39.1    8.04   1.07527  ...    9.47505     0.99355
# ...

# %%
df.head()
# Out:
#                      iso_a3 currency_code  local_price  dollar_ex  GDP_dollar
# date       Country
# 2000-04-01 Argentina    ARG           ARS         2.50   1.000000         NaN
#            Australia    AUS           AUD         2.59   1.680000         NaN
#            Brazil       BRA           BRL         2.95   1.790000         NaN
#            Britain      GBR           GBP         1.90   0.632911         NaN
#            Canada       CAN           CAD         2.85   1.470000         NaN

# %%
df.swaplevel()
# Out:
#                                 iso_a3 currency_code  local_price  \
# Country              date
# Argentina            2000-04-01    ARG           ARS         2.50
# Australia            2000-04-01    AUS           AUD         2.59
# Brazil               2000-04-01    BRA           BRL         2.95
# Britain              2000-04-01    GBR           GBP         1.90
# Canada               2000-04-01    CAN           CAD         2.85
# ...                                ...           ...          ...
# Ukraine              2019-07-09    UKR           UAH        57.00
# United Arab Emirates 2019-07-09    ARE           AED        14.75
# United States        2019-07-09    USA           USD         5.74
# Uruguay              2019-07-09    URY           UYU       164.00
# Vietnam              2019-07-09    VNM           VND     65000.00
#
#                                     dollar_ex  GDP_dollar
# Country              date
# Argentina            2000-04-01      1.000000         NaN
# ...

# %%
df1=df.stack()

# %%
df1.unstack(2)
# Out:
#                                 iso_a3 currency_code local_price dollar_ex  \
# date       Country
# 2000-04-01 Argentina               ARG           ARS         2.5         1
#            Australia               AUS           AUD        2.59      1.68
#            Brazil                  BRA           BRL        2.95      1.79
#            Britain                 GBR           GBP         1.9  0.632911
#            Canada                  CAN           CAD        2.85      1.47
# ...                                ...           ...         ...       ...
# 2019-07-09 Ukraine                 UKR           UAH          57   25.6475
#            United Arab Emirates    ARE           AED       14.75   3.67315
#            United States           USA           USD        5.74         1
#            Uruguay                 URY           UYU         164   35.1695
#            Vietnam                 VNM           VND       65000     23231
#
#                                 GDP_dollar
# ...
