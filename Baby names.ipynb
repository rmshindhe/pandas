# %% [markdown]
# #### The is a dataset hosted by the City of New York. The city has an open data platform and they update their information according the amount of data that is brought in. Data were collected through civil birth registration. Each record represents the ranking of a baby name in the order of frequency. Data can be used to represent the popularity of a name.
#
# The task is to seperate the male and female baby names and write them into a excel file with diffrent sheets.

# %%
import pandas as pd
URL="https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD"
baby_names = pd.read_csv(URL)

# %%
baby_names.head()
# Out:
#    Year of Birth  Gender Ethnicity         BN  Count  Rank
# 0           2011  FEMALE  HISPANIC  GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC        GIA     21    67
# 2           2011  FEMALE  HISPANIC     GIANNA     49    42
# 3           2011  FEMALE  HISPANIC    GISELLE     38    51
# 4           2011  FEMALE  HISPANIC      GRACE     36    53

# %%
baby_names.axes
# Out:
# [RangeIndex(start=0, stop=19418, step=1),
#  Index(['Year of Birth', 'Gender', 'Ethnicity', 'Child's First Name', 'Count',
#         'Rank'],
#        dtype='object')]

# %%
baby_names.rename(columns={"Child's First Name":"BN"})
# Out:
#        Year of Birth  Gender                   Ethnicity         BN  Count  \
# 0               2011  FEMALE                    HISPANIC  GERALDINE     13
# 1               2011  FEMALE                    HISPANIC        GIA     21
# 2               2011  FEMALE                    HISPANIC     GIANNA     49
# 3               2011  FEMALE                    HISPANIC    GISELLE     38
# 4               2011  FEMALE                    HISPANIC      GRACE     36
# ...              ...     ...                         ...        ...    ...
# 19413           2016  FEMALE                    HISPANIC     Alayna     10
# 19414           2015  FEMALE                    HISPANIC    Yaritza     12
# 19415           2015    MALE          WHITE NON HISPANIC     Mendel     42
# 19416           2016    MALE  ASIAN AND PACIFIC ISLANDER      Isaac     21
# 19417           2015  FEMALE          WHITE NON HISPANIC    Alessia     12
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
baby_names["Child's First Name"].to_frame()
" , ".join(str(name) for name in baby_names["Child's First Name"])
# Out:
# "GERALDINE , GIA , GIANNA , GISELLE , GRACE , GUADALUPE , HAILEY , HALEY , HANNAH , HAYLEE , HAYLEY , HAZEL , HEAVEN , HEIDI , HEIDY , HELEN , IMANI , INGRID , IRENE , IRIS , ISABEL , ISABELA , ISABELLA , ISABELLE , ISIS , ITZEL , IZABELLA , JACQUELINE , JADA , JADE , JAELYNN , JAMIE , JANELLE , JASLENE , JASMIN , JASMINE , JAYDA , JAYLA , JAYLAH , JAYLEEN , JAYLENE , JAYLIN , JAYLYN , JAZLYN , JAZMIN , JAZMINE , JENNIFER , JESSICA , JIMENA , JOCELYN , JOHANNA , JOSELYN , JULIA , JULIANA , JULIANNA , JULIET , JULIETTE , JULISSA , KAELYN , KAILEY , KAILYN , KAITLYN , KAMILA , KAREN , KARLA , KATE , KATELYN , KATELYNN , KATHERINE , KATIE , KAYLA , KAYLEE , KAYLEEN , KAYLEIGH , KAYLIE , KAYLIN , KEILY , KELLY , KEYLA , KHLOE , KIARA , KIMBERLY , KRYSTAL , KYLEE , KYLIE , LAILA , LAURA , LAUREN , LAYLA , LEA , LEAH , LEILA , LEILANI , LESLEY , LESLIE , LESLY , LEYLA , LIA , LIANA , LILIANA , LILY , LINDSAY , LIZBETH , LONDON , LUCIA , LUNA , LUZ , MADELINE , MADELYN , MADISON , MAKAYLA ,
# ...

# %%
baby_names.to_csv("NYC Baby Names.csv", index= False, columns = ['Year of Birth', 'Ethnicity', "Child's First Name", 'Count',
        'Rank'],encoding="utf-8")

# %%
pd.read_csv("NYC Baby Names.csv")
# Out:
#        Year of Birth                   Ethnicity Child's First Name  Count  \
# 0               2011                    HISPANIC          GERALDINE     13
# 1               2011                    HISPANIC                GIA     21
# 2               2011                    HISPANIC             GIANNA     49
# 3               2011                    HISPANIC            GISELLE     38
# 4               2011                    HISPANIC              GRACE     36
# ...              ...                         ...                ...    ...
# 19413           2016                    HISPANIC             Alayna     10
# 19414           2015                    HISPANIC            Yaritza     12
# 19415           2015          WHITE NON HISPANIC             Mendel     42
# 19416           2016  ASIAN AND PACIFIC ISLANDER              Isaac     21
# 19417           2015          WHITE NON HISPANIC            Alessia     12
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
baby_names.columns=['Year of Birth', 'Gender', 'Ethnicity', 'BN', 'Count',
        'Rank']

# %%
mask=baby_names['Gender']=="FEMALE"
girls=baby_names[mask]
girls
# Out:
#        Year of Birth  Gender           Ethnicity         BN  Count  Rank
# 0               2011  FEMALE            HISPANIC  GERALDINE     13    75
# 1               2011  FEMALE            HISPANIC        GIA     21    67
# 2               2011  FEMALE            HISPANIC     GIANNA     49    42
# 3               2011  FEMALE            HISPANIC    GISELLE     38    51
# 4               2011  FEMALE            HISPANIC      GRACE     36    53
# ...              ...     ...                 ...        ...    ...   ...
# 19408           2016  FEMALE            HISPANIC   Nathalie     11    73
# 19411           2015  FEMALE            HISPANIC    Joselyn     12    79
# 19413           2016  FEMALE            HISPANIC     Alayna     10    74
# 19414           2015  FEMALE            HISPANIC    Yaritza     12    79
# 19417           2015  FEMALE  WHITE NON HISPANIC    Alessia     12    81
#
# [9933 rows x 6 columns]

# %%
mask1=baby_names['Gender'] =="MALE"
boys=baby_names[mask1]
boys
# Out:
#        Year of Birth Gender                   Ethnicity        BN  Count  Rank
# 545             2011   MALE  ASIAN AND PACIFIC ISLANDER     AARAV     15    51
# 546             2011   MALE  ASIAN AND PACIFIC ISLANDER     AARON     51    19
# 547             2011   MALE  ASIAN AND PACIFIC ISLANDER     ABDUL     20    46
# 548             2011   MALE  ASIAN AND PACIFIC ISLANDER  ABDULLAH     30    36
# 549             2011   MALE  ASIAN AND PACIFIC ISLANDER      ADAM     28    38
# ...              ...    ...                         ...       ...    ...   ...
# 19409           2016   MALE          WHITE NON HISPANIC   Cheskel     20    89
# 19410           2015   MALE          WHITE NON HISPANIC    Arthur     29    75
# 19412           2015   MALE          WHITE NON HISPANIC      Joel     32    72
# 19415           2015   MALE          WHITE NON HISPANIC    Mendel     42    64
# 19416           2016   MALE  ASIAN AND PACIFIC ISLANDER     Isaac     21    48
#
# [9485 rows x 6 columns]

# %%
baby_names["Gender"]
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 19413    FEMALE
# 19414    FEMALE
# 19415      MALE
# 19416      MALE
# 19417    FEMALE
# Name: Gender, Length: 19418, dtype: object

# %%
excel_file = pd.ExcelWriter("Baby Names.xlsx")

# %%
girls.to_excel(excel_file,sheet_name = "Girl", index=False)
boys.to_excel(excel_file,sheet_name = "boy", index = False)

# %%
excel_file.save()
